# %% [markdown]
# <a href="https://colab.research.google.com/github/palakdawra4/BigDataAnalysis/blob/main/assignment6_8Apr_202301041.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd
data=pd.read_csv("Country-data.csv")
data1=data[["health","child_mort"]]
k=KMeans(n_clusters=2,n_init=10)
k.fit(data1)
plt.scatter(data1["health"],data1["child_mort"],c=k.labels_)
plt.show()
